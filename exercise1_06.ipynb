# %%
import pandas as pd
import matplotlib.pyplot as plt #import plotting package

#render plotting automatically
# %matplotlib inline 

import matplotlib as mpl #additional plotting functionality

mpl.rcParams['figure.dpi'] = 400 #high resolution figures

# %%
df_clean_2 = pd.read_csv(r'C:\Users\gabri\OneDrive\Documentos\Data Science Projects with Python\df_clean_2.csv')

# %%
df_clean_2.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24      2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26     -1      2
# 2  85698822-43f5      90000    2          2         2   34      0      0
# 3  0737c11b-be42      50000    2          2         1   37      0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57     -1      0
#
#    PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0     -1     -1  ...          0          0          0         0       689
# 1      0      0  ...       3272       3455       3261         0      1000
# 2      0      0  ...      14331      14948      15549      1518      1500
# 3      0      0  ...      28314      28959      29547      2000      2019
# 4     -1      0  ...      20940      19146      19131      2000     36681
#
#    PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df_clean_2[['LIMIT_BAL', 'AGE']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'LIMIT_BAL'}>,
#         <AxesSubplot:title={'center':'AGE'}>]], dtype=object)

# %%
df_clean_2[['LIMIT_BAL', 'AGE']].describe()
# Out:
#            LIMIT_BAL           AGE
# count   26664.000000  26664.000000
# mean   167919.054905     35.505213
# std    129839.453081      9.227442
# min     10000.000000     21.000000
# 25%     50000.000000     28.000000
# 50%    140000.000000     34.000000
# 75%    240000.000000     41.000000
# max    800000.000000     79.000000

# %%
df_clean_2['EDUCATION'].value_counts()
# Out:
# 2    12458
# 1     9412
# 3     4380
# 5      245
# 4      115
# 6       43
# 0       11
# Name: EDUCATION, dtype: int64

# %%
df_clean_2['EDUCATION'].replace(to_replace=[0,5,6], value=4, inplace=True)
df_clean_2['EDUCATION'].value_counts()
# Out:
# 2    12458
# 1     9412
# 3     4380
# 4      414
# Name: EDUCATION, dtype: int64

# %%
df_clean_2['MARRIAGE'].value_counts()
# Out:
# 2    14158
# 1    12172
# 3      286
# 0       48
# Name: MARRIAGE, dtype: int64

# %%
df_clean_2['MARRIAGE'].replace(to_replace=0, value=3, inplace=True)
df_clean_2['MARRIAGE'].value_counts()
# Out:
# 2    14158
# 1    12172
# 3      334
# Name: MARRIAGE, dtype: int64

# %%
df_clean_2.to_csv(r'C:\Users\gabri\OneDrive\Documentos\Data Science Projects with Python\df_clean_2_01.csv', index=False)

# %%
df_clean_2 = pd.read_csv(r'C:\Users\gabri\OneDrive\Documentos\Data Science Projects with Python\df_clean_2_01.csv')
df_clean_2.groupby('EDUCATION').agg({'default payment next month':'mean'}).plot.bar(legend=False)

plt.ylabel('Default rate')
plt.xlabel('Education level: ordinal enconding')

# 1- graduate school, 2- university, 3- high school, 4- others
# Out:
# Text(0.5, 0, 'Education level: ordinal enconding')

# %%
df_clean_2['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 4], dtype=int64)
